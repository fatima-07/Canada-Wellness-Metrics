# %% [markdown]
# # 02 · Data Cleaning
#
# | | |
# |---|---|
# | **Project** | Mental Health & Suicide Prevention Data Analysis (Canada) |
# | **Pipeline step** | 2 of 10 |
# | **Author** | Fatima and Danny |
# | **Status** | ✅ Team reviewed and agreed |
# | **Date** | 2026-09-01 |
# | **Audit report** | `reports/Report 3 - Data Cleaning and Bug Fixes.md` |
#
# ---
#
# ## Overview
#
# This notebook cleans all eight raw datasets and writes tidy outputs to `data/processed/02_cleaned/`.
#
# **Datasets processed**
#
# | Key | Source | Cleaner |
# |---|---|---|
# | `perceived_mh_annual` | StatCan 13-10-0972 | `clean_statcan_long` |
# | `suicidal_thoughts` | StatCan catalogue | `clean_statcan_long` |
# | `stress_coping` | StatCan catalogue | `clean_statcan_long` |
# | `perceived_health_quarterly` | StatCan catalogue | `clean_statcan_long` |
# | `cchs_mh_disorders` | StatCan catalogue (160 992 rows) | `clean_statcan_long` |
# | `cihi_mh_services` | CIHI chart-config CSV | `clean_cihi_vizconfig` |
# | `cihi_children_youth` | CIHI Excel workbook (2 sheets) | `clean_cihi_children_youth` |
# | `mhacs_2022_pumf` | StatCan MHACS 2022 PUMF microdata | `clean_mhacs_pumf` |
#
# **Notebook structure**
#
# | Section | Purpose |
# |---|---|
# | §1 Libraries | Import dependencies |
# | §2 Paths | Resolve `data/raw` and `data/processed` roots |
# | §3 Load | Load all raw datasets into memory |
# | §4 Cleaning functions | Define all four cleaning functions |
# | §5 Run pipeline | Apply cleaners and write processed CSVs |

# %% [markdown]
# ## §1 · Libraries
#
# Standard library and third-party imports used throughout the notebook.
# `re` is required by `clean_cihi_children_youth` for dynamic year-column detection.

# %%
import re
import warnings
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 40)
pd.set_option("display.width", 160)
print("pandas", pd.__version__, "| numpy", np.__version__)
# Out:
# pandas 2.2.2 | numpy 2.2.5

# %% [markdown]
# ## §2 · Paths
#
# `find_root` walks up the directory tree until it locates `data/raw/`, so the notebook runs correctly whether launched from the repo root or from the `notebooks/` folder.

# %%
def find_root(start: Path) -> Path:
    """Walk up until we find the folder that contains data/raw (works from repo root or /notebooks)."""
    for p in [start, *start.parents]:
        if (p / "data" / "raw").is_dir():
            return p
    raise FileNotFoundError("Could not find data/raw above " + str(start))

ROOT = find_root(Path.cwd())
RAW = ROOT / "data" / "raw"
PROCESSED = ROOT / "data" / "processed"
PROCESSED.mkdir(parents=True, exist_ok=True)

print("root     :", ROOT)
print("raw      :", RAW)
print("processed:", PROCESSED)
# Out:
# root     : /home/codespace/NewProject/Data-Analyst-Mental-Health-Project
# raw      : /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/raw
# processed: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed

# %% [markdown]
# ## §3 · Load raw datasets
#
# All eight raw files are registered in `DATASETS`. StatCan CSVs use `utf-8-sig` encoding (byte-order mark). The CIHI Excel workbook contains two machine-readable hidden sheets (`Table8DATA_to hide`, `Table13DATA_to hide`); these are parsed with `header=None` and reconstructed using row 1 as the column header.

# %%
DATASETS = {
    "perceived_mh_annual":        {"file": "StatCan 13-10-0972 – perceived mental health.csv",                                              "kind": "statcan_long"},
    "suicidal_thoughts":          {"file": "Catalogue Entry Mental health characteristics and suicidal thoughts.csv",                        "kind": "statcan_long_dual"},
    "stress_coping":              {"file": "Catalogue Entry Mental health characteristics Ability to handle stress and sources of stress.csv","kind": "statcan_long_dual"},
    "perceived_health_quarterly": {"file": "Catalogue Entry Mental health indicators.csv",                                                   "kind": "statcan_long_dual"},
    "cchs_mh_disorders":          {"file": "Catalogue Entry Perceived health, by gender and province.csv",                                   "kind": "statcan_long_dual"},
    "cihi_mh_services":           {"file": "health services for mental illness and alcoholdrug induced disorders.csv",                       "kind": "cihi_vizconfig"},
    "cihi_children_youth":        {"file": "care-children-youth-with-mental-disorders-data-tables-en.xlsx",                                  "kind": "excel_multitable"},
    "mhacs_2022_pumf":            {"file": "MHACS 2022 Public Use Microdata.csv",                                                            "kind": "microdata"},
}


def load_dataset(key: str) -> pd.DataFrame:
    """Load a single CSV dataset from data/raw using the DATASETS registry."""
    spec = DATASETS[key]
    path = RAW / spec["file"]
    if spec["kind"] in ("statcan_long", "statcan_long_dual", "cihi_vizconfig"):
        return pd.read_csv(path, encoding="utf-8-sig", low_memory=False)
    if spec["kind"] == "microdata":
        return pd.read_csv(path, low_memory=False)
    raise ValueError(f"{key}: kind={spec['kind']} is loaded separately (see Excel block below)")


# Load all CSV-backed datasets
raw = {k: load_dataset(k) for k, v in DATASETS.items() if v["kind"] != "excel_multitable"}

# Load the CIHI Excel workbook: parse only the two hidden data sheets.
_xls = pd.ExcelFile(RAW / DATASETS["cihi_children_youth"]["file"])
raw_excel = {}
for _sheet in [s for s in _xls.sheet_names if s.endswith("_to hide")]:
    _t    = _xls.parse(_sheet, header=None)
    _body = _t.iloc[2:].reset_index(drop=True)
    _body.columns = [str(h).replace("\n", " ").strip() for h in _t.iloc[1]]
    raw_excel[_sheet] = _body

# Report shapes
for k, df in raw.items():
    print(f"{k:28} {df.shape}")
for k, df in raw_excel.items():
    print(f"{k:28} {df.shape}  (excel)")
# Out:
# perceived_mh_annual          (936, 18)
# suicidal_thoughts            (8208, 18)
# stress_coping                (27360, 18)
# perceived_health_quarterly   (6318, 17)
# cchs_mh_disorders            (160992, 18)
# cihi_mh_services             (264, 14)
# mhacs_2022_pumf              (9861, 602)
# Table8DATA_to hide           (216, 13)  (excel)
# Table13DATA_to hide          (216, 13)  (excel)

# %% [markdown]
# ## §4 · Cleaning functions
#
# The four functions below cover every dataset in the pipeline. All bugs and warnings identified during the team code review (Report 3, 2026-09-01) are resolved.
#
# | Function | Datasets | What it produces |
# |---|---|---|
# | `clean_statcan_long` | 5 StatCan CSVs | Tidy long table; `Percent` / `Low 95%` / `High 95%` characteristics pivoted to `value`, `ci_low`, `ci_high` columns |
# | `clean_cihi_vizconfig` | `cihi_mh_services` | One row per x/y pair: `indicator`, `breakdown`, `group`, `value`, `ci_low`, `ci_high` |
# | `clean_cihi_children_youth` | CIHI Excel (2 sheets) | Long format; CI strings parsed to `ci_low`/`ci_high`; point estimate preserved in `value` |
# | `clean_mhacs_pumf` | MHACS 2022 PUMF | Missing-value codes replaced with `NaN` for all numeric D-prefix variables |

# %%
def clean_statcan_long(df: pd.DataFrame, target_uom: str = "Percent") -> pd.DataFrame:
    """Clean a StatCan long-format CSV for a specific target UOM ('Percent' or 'Number').
    Pivots confidence intervals (Low/High 95%) and point estimates into distinct columns.
    Applies SCALAR_FACTOR scaling (e.g. thousands -> x1000) and standardizes uom/metric_type.
    """
    df = df.copy()

    # --- 1. Normalise column names -------------------------------------------
    df.columns = df.columns.str.strip().str.lower()
    for col in df.select_dtypes(include="object").columns:
        df[col] = df[col].str.strip()

    rename_map = {
        "age group": "age_group", "indicators": "indicator", "characteristics": "characteristic",
        "statistics": "statistic", "ref_date": "ref_date", "value": "value", "dguid": "dguid",
        "uom_id": "uom_id", "scalar_factor": "scalar_factor", "scalar_id": "scalar_id",
        "vector": "vector", "coordinate": "coordinate", "status": "quality_flag",
    }
    df.rename(columns=rename_map, inplace=True)
    if "gender" in df.columns:
        df.rename(columns={"gender": "sex"}, inplace=True)

    if "characteristic" not in df.columns and "statistic" in df.columns:
        df["characteristic"] = df["statistic"]

    # Filter by target UOM if 'uom' exists and target_uom is specified
    if "uom" in df.columns and target_uom:
        df = df[df["uom"].astype(str).str.lower() == target_uom.lower()].copy()

    # --- 2. Parse reference dates --------------------------------------------
    df["ref_date_raw"] = df["ref_date"].astype(str).str.strip()
    df["start_year"] = pd.to_numeric(
        df["ref_date_raw"].str.extract(r"^(\d{4})")[0], errors="coerce"
    ).astype("Int64")

    # --- 3. Numeric values and scalar factors --------------------------------
    if "value" in df.columns:
        df["value"] = pd.to_numeric(df["value"], errors="coerce")

    # Apply scalar factor: if 'thousands', multiply value by 1000
    if "scalar_factor" in df.columns and "value" in df.columns:
        thousands_mask = df["scalar_factor"].astype(str).str.lower().eq("thousands")
        df.loc[thousands_mask, "value"] *= 1000

    # --- 4. Clean quality flags ----------------------------------------------
    if "quality_flag" in df.columns:
        df["quality_flag"] = df["quality_flag"].astype(str).str.upper().str.strip()
        df["quality_flag"] = df["quality_flag"].replace({"NAN": np.nan, "NONE": np.nan, "": np.nan})
    else:
        df["quality_flag"] = np.nan

    # --- 5. Normalise geography and indicator text ---------------------------
    if "geo" in df.columns:
        df["geo"] = df["geo"].str.replace(" / ", "/", regex=False).str.strip()
    if "indicator" in df.columns:
        df["indicator"] = df["indicator"].str.replace(r"\s+", " ", regex=True).str.strip()

    # Core dimensions for aggregation / pivoting
    core_dims = ["ref_date_raw", "start_year", "geo", "sex", "age_group", "indicator"]
    dim_cols = [c for c in core_dims if c in df.columns]

    # --- 6. Pivot Point Estimate and CI Low / High --------------------------
    if "characteristic" in df.columns:
        char = df["characteristic"].fillna("").astype(str)

        is_low = char.str.contains(r"(?:low|lower).*95%", case=False, regex=True)
        is_high = char.str.contains(r"(?:high|upper).*95%", case=False, regex=True)

        if target_uom.lower() == "percent":
            is_val = ~is_low & ~is_high & (char.str.contains("percent", case=False, regex=True) | char.eq("Percent"))
        else:
            is_val = ~is_low & ~is_high & (char.str.contains("number", case=False, regex=True) | char.eq("Number of persons"))

        if (is_low.any() or is_high.any()) and is_val.any():
            df["_char_key"] = np.select(
                [is_val, is_low, is_high],
                ["value", "ci_low", "ci_high"],
                default="other",
            )

            # Preserve quality_flag from point estimate rows
            flag_df = None
            if "quality_flag" in df.columns:
                flag_df = df[df["_char_key"] == "value"][dim_cols + ["quality_flag"]].drop_duplicates(subset=dim_cols)

            pivot = (
                df[df["_char_key"] != "other"]
                .pivot_table(
                    index=dim_cols,
                    columns="_char_key",
                    values="value",
                    aggfunc="first",
                )
                .reset_index()
            )
            pivot.columns.name = None

            if flag_df is not None and not flag_df.empty:
                pivot = pivot.merge(flag_df, on=dim_cols, how="left")

            df = pivot

    # --- 7. Standardize uom and metric_type -----------------------------------
    uom_val = target_uom.lower() if target_uom else "unknown"
    df["uom"] = uom_val
    df["metric_type"] = uom_val

    # --- 8. Reorder columns ---------------------------------------------------
    col_order = [
        "ref_date_raw", "start_year", "geo", "sex", "age_group", "indicator",
        "value", "ci_low", "ci_high", "uom", "metric_type", "quality_flag"
    ]
    cols_present = [c for c in col_order if c in df.columns]
    other_cols = [c for c in df.columns if c not in cols_present]
    df = df[cols_present + other_cols]

    return df

# %%
def clean_cihi_vizconfig(df: pd.DataFrame) -> pd.DataFrame:
    """Unpivot a CIHI chart-config CSV into one tidy row per data point with metric_type and cleaned group.
    
    Extracts explicit metric_type (percent, mean_score, rate_per_100k_pop, rate_per_100k_presentations)
    and resolves Excel date string corruption in age groups (e.g. '14-Oct' -> '10-14').
    """
    df = df.copy()
    df.columns = df.columns.str.strip().str.lower()

    required = {"x_axis_values", "y_axis_values"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"clean_cihi_vizconfig: missing columns {missing}")

    df["x_axis_values"] = df["x_axis_values"].astype(str).str.split(",")
    df["y_axis_values"] = df["y_axis_values"].astype(str).str.split(",")

    metric_type_map = {
        "Percentage (%)": "percent",
        "Mean": "mean_score",
        "Rate per 100,000 population": "rate_per_100k_pop",
        "Rate per 100,000 presentations": "rate_per_100k_presentations"
    }

    month_num = {
        "Jan": "1", "Feb": "2", "Mar": "3", "Apr": "4", "May": "5", "Jun": "6",
        "Jul": "7", "Aug": "8", "Sep": "9", "Oct": "10", "Nov": "11", "Dec": "12"
    }

    tidy_rows = []
    for _, row in df.iterrows():
        indicator = row.get("indicator", "")
        raw_y_label = str(row.get("y_axis_label", "")).strip()
        metric_type = metric_type_map.get(raw_y_label, "unknown")

        xs = row["x_axis_values"]
        ys = row["y_axis_values"]
        n = min(len(xs), len(ys))

        for i in range(n):
            x = xs[i].strip()
            y = ys[i].strip()
            value = pd.to_numeric(y, errors="coerce")

            # Fix Excel date string corruption in age groups (e.g. "14-Oct" -> "10-14")
            if "-" in x:
                parts = x.split("-")
                if len(parts) == 2:
                    p1, p2 = parts[0].strip(), parts[1].strip()
                    if p1.isdigit() and p2 in month_num:
                        x = f"{month_num[p2]}-{p1}"
                    elif p2.isdigit() and p1 in month_num:
                        x = f"{month_num[p1]}-{p2}"

            tidy_rows.append({
                "indicator": indicator,
                "breakdown": row.get("vis_option", None),
                "group": x,
                "value": value,
                "ci_low": pd.to_numeric(row.get("confidence_interval_low", None), errors="coerce"),
                "ci_high": pd.to_numeric(row.get("confidence_interval_high", None), errors="coerce"),
                "metric_type": metric_type,
                "unit_label": raw_y_label,
            })

    tidy = pd.DataFrame(tidy_rows)
    tidy = tidy.dropna(subset=["value"])
    return tidy

# %%
# Module-level constants for CI string parsing
_CI_DASH_CHARS = {"-", "\u2013", "\u2014"}       # ASCII hyphen, en-dash, em-dash
_CI_PATTERN    = r"([\d.]+)\s*[-\u2013\u2014]\s*([\d.]+)"  # matches "12.3-14.5" and variants


def clean_cihi_children_youth(raw_excel: dict) -> pd.DataFrame:
    """Reshape the CIHI children/youth Excel workbook from wide to long format.

    Parameters
    ----------
    raw_excel : dict[str, pd.DataFrame]
        Mapping of sheet name to raw DataFrame, as produced by the §3 loader.

    Returns
    -------
    pd.DataFrame
        Combined long-format DataFrame with columns:
        id columns | fiscal_year | value | ci_low | ci_high | sheet_type

    Notes
    -----
    - Year columns are detected dynamically via regex so future fiscal years are
      included automatically without code changes.
    - Cells formatted as CI ranges (e.g. '12.3-14.5') are split into ci_low and
      ci_high; the lower bound is written back as the point estimate in value.
    - All three dash variants (hyphen, en-dash, em-dash) are recognised.
    """
    frames = []

    for sheet, df in raw_excel.items():
        df = df.copy()
        df.columns = df.columns.str.strip().str.replace("\n", " ")

        # Detect year columns dynamically (any column whose name contains a 4-digit year)
        year_cols  = [c for c in df.columns if re.search(r"\b\d{4}\b", str(c))]
        id_cols    = [c for c in df.columns if c not in year_cols] if year_cols else list(df.columns[:3])
        value_cols = year_cols if year_cols else list(df.columns[3:])

        # Melt from wide (one column per fiscal year) to long format
        long_df = df.melt(
            id_vars=id_cols,
            value_vars=value_cols,
            var_name="fiscal_year",
            value_name="value",
        )
        long_df["fiscal_year"] = long_df["fiscal_year"].str.replace(" ", "", regex=False)

        # Reset index to ensure label-safe assignment with .loc below
        long_df = long_df.reset_index(drop=True)

        long_df["ci_low"]  = None
        long_df["ci_high"] = None

        # Parse CI range strings (e.g. '12.3-14.5') into separate bounds.
        # .items() is used so idx is the real label index, not a counter,
        # ensuring .loc[idx] always writes to the correct row.
        for idx, val in long_df["value"].items():
            if isinstance(val, str) and any(d in val for d in _CI_DASH_CHARS):
                match = pd.Series(val).str.extract(_CI_PATTERN, expand=True)
                if not match.empty and pd.notna(match.iloc[0, 0]):
                    lo = pd.to_numeric(match.iloc[0, 0], errors="coerce")
                    hi = pd.to_numeric(match.iloc[0, 1], errors="coerce")
                    long_df.loc[idx, "ci_low"]  = lo
                    long_df.loc[idx, "ci_high"] = hi
                    # Replace the raw CI string with the numeric point estimate
                    long_df.loc[idx, "value"]   = lo

        # Convert value column to numeric (CI strings are already resolved above)
        long_df["value"] = pd.to_numeric(long_df["value"], errors="coerce")

        # Assign a human-readable sheet type identifier
        long_df["sheet_type"] = (
            "ED"              if "Table8"  in sheet else
            "Hospitalization" if "Table13" in sheet else
            sheet.replace("_to hide", "")
        )
        frames.append(long_df)

    return pd.concat(frames, ignore_index=True)

# %%
import pandas as pd
import numpy as np

# ============================================================
# 1. CODEBOOK MAPPINGS
# ============================================================

GENDER_MAP = {
    1: "Male",
    2: "Female",
    3: "Non-binary",
    9: "Not stated",
}

MARITAL_MAP = {
    1: "Married",
    2: "Common-law",
    3: "Widowed",
    4: "Separated",
    5: "Divorced",
    99: "Not stated",
}

PERCEIVED_MH_MAP = {
    1: "Excellent",
    2: "Very good",
    3: "Good",
    4: "Fair",
    5: "Poor",
    9: "Not stated",
}

AGE_GROUP_MAP = {
    1: "12–17",
    2: "18–24",
    3: "25–44",
    4: "45–64",
    5: "65+"
}

CODEBOOK = {
    "GENDER": GENDER_MAP,
    "DHHGMS": MARITAL_MAP,
    "GEN_01": PERCEIVED_MH_MAP,
}


def decode_codebook(df):
    df = df.copy()
    for col, mapping in CODEBOOK.items():
        if col in df.columns:
            df[f"{col}_LABEL"] = df[col].map(mapping)
    return df


# ============================================================
# 2. CLEANING FUNCTION
# ============================================================

def clean_mhacs_pumf(df):
    df = df.copy()

    df = df.replace(r'^\s*$', np.nan, regex=True)

    missing_codes = {6, 7, 8, 9, 96, 996, 999, 99.6}

    # Convert object → numeric where possible
    for col in df.columns:
        if df[col].dtype == "object":
            df[col] = pd.to_numeric(df[col], errors="ignore")

    # Replace StatCan missing codes with NaN
    numeric_cols = [c for c in df.columns if df[c].dtype in ("int64", "float64")]
    for col in numeric_cols:
        df[col] = df[col].replace(list(missing_codes), np.nan)

    # Decode categorical variables
    df = decode_codebook(df)

    # Age group numeric
    if "DHHGAGE" in df.columns:
        df["DHHGAGE"] = pd.to_numeric(df["DHHGAGE"], errors="coerce")

    # Income cleaning
    income_vars = [c for c in df.columns if c.startswith("INCDV")]
    for col in income_vars:
        df[col] = pd.to_numeric(df[col], errors="coerce").clip(lower=0)

    # Weight cleaning
    if "WTS_M" in df.columns:
        df["WTS_M"] = pd.to_numeric(df["WTS_M"], errors="coerce")
        df["WTS_M"] = df["WTS_M"].fillna(df["WTS_M"].median())

    df.columns = [c.upper() for c in df.columns]

    return df


# ============================================================
# 3. MISSING-VALUE STRATEGY (FIXED)
# ============================================================

def apply_missing_strategy(df):
    df = df.copy()

    # 1. Age group labels
    df["DHHGAGE_LABEL"] = df["DHHGAGE"].map(AGE_GROUP_MAP)
    df["DHHGAGE_LABEL"] = df["DHHGAGE_LABEL"].fillna("Not stated")

    # 2. Fill ALL *_LABEL columns with "Not stated"
    label_cols = [c for c in df.columns if c.endswith("_LABEL")]
    for col in label_cols:
        df[col] = df[col].fillna("Not stated")

    # 3. Income imputation
    income_vars = [c for c in df.columns if c.startswith("INCDV")]
    for col in income_vars:
        df[col] = df[col].fillna(df[col].median())

    # 4. Mental-health skip-pattern variables → keep NaN
    return df


# ============================================================
# 4. FINAL PIPELINE
# ============================================================

def load_mhacs(path):
    return pd.read_csv(path)

def build_analysis_dataset_df(df_raw):
    df_clean = clean_mhacs_pumf(df_raw)
    df_final = apply_missing_strategy(df_clean)

    # Remove rows with missing gender (16 rows)
    df_final = df_final.dropna(subset=["GENDER"])

    return df_final

# %% [markdown]
# ## §5 · Run pipeline
#
# Applies the four cleaning functions to every dataset and writes the results to `data/processed/02_cleaned/`. Each output file is named after its dataset key (e.g. `perceived_mh_annual.csv`).

# %%
CLEANED = ROOT / "data" / "processed" / "02_cleaned"
CLEANED.mkdir(parents=True, exist_ok=True)

def safe_save_csv(df: pd.DataFrame, path: Path):
    """Safely save a DataFrame to CSV, falling back to shared r+ if file is open in a viewer."""
    try:
        df.to_csv(path, index=False)
    except PermissionError:
        try:
            with open(path, "r+", encoding="utf-8", newline="") as f:
                f.seek(0)
                df.to_csv(f, index=False)
                f.truncate()
        except Exception:
            alt_path = path.with_name(f"{path.stem}_new{path.suffix}")
            df.to_csv(alt_path, index=False)
            print(f"  Warning: {path.name} was locked, saved to {alt_path.name}")
            return
    print(f"  Successfully saved: {path.name} (shape={df.shape})")

cleaned: dict[str, pd.DataFrame] = {}

for key, spec in DATASETS.items():
    print(f"\n=== Cleaning {key} ===")
    file_path = RAW / spec["file"]

    if spec["kind"] == "statcan_long_dual":
        raw_df = pd.read_csv(file_path, encoding="utf-8-sig", low_memory=False)
        pct_df = clean_statcan_long(raw_df, target_uom="Percent")
        n_df = clean_statcan_long(raw_df, target_uom="Number")

        # Save _pct.csv, _n.csv, and backward-compatible base file
        safe_save_csv(pct_df, CLEANED / f"{key}_pct.csv")
        safe_save_csv(n_df, CLEANED / f"{key}_n.csv")
        safe_save_csv(pct_df, CLEANED / f"{key}.csv")
        cleaned[f"{key}_pct"] = pct_df
        cleaned[f"{key}_n"] = n_df
        cleaned[key] = pct_df

    elif spec["kind"] == "statcan_long":
        raw_df = pd.read_csv(file_path, encoding="utf-8-sig", low_memory=False)
        clean_df = clean_statcan_long(raw_df, target_uom="Percent")
        safe_save_csv(clean_df, CLEANED / f"{key}.csv")
        cleaned[key] = clean_df

    elif spec["kind"] == "cihi_vizconfig":
        raw_df = pd.read_csv(file_path, encoding="utf-8-sig", low_memory=False)
        clean_df = clean_cihi_vizconfig(raw_df)
        safe_save_csv(clean_df, CLEANED / f"{key}.csv")
        cleaned[key] = clean_df

    elif spec["kind"] == "excel_multitable":
        clean_df = clean_cihi_children_youth(raw_excel)
        safe_save_csv(clean_df, CLEANED / f"{key}.csv")
        cleaned[key] = clean_df

    elif spec["kind"] == "microdata":
        raw_df = pd.read_csv(file_path, low_memory=False)
        clean_df = build_analysis_dataset_df(raw_df)
        safe_save_csv(clean_df, CLEANED / f"{key}.csv")
        cleaned[key] = clean_df

print("\nALL DATASETS CLEANED & VERIFIED ✔")
# Out:
# === Cleaning perceived_mh_annual ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/perceived_mh_annual.csv  shape=(936, 19)
#
# === Cleaning suicidal_thoughts ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/suicidal_thoughts.csv  shape=(4994, 19)
#
# === Cleaning stress_coping ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/stress_coping.csv  shape=(14388, 19)
#
# === Cleaning perceived_health_quarterly ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/perceived_health_quarterly.csv  shape=(6318, 18)
#
# === Cleaning cchs_mh_disorders ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/cchs_mh_disorders.csv  shape=(74036, 19)
#
# === Cleaning cihi_mh_services ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/cihi_mh_services.csv  shape=(263, 6)
#
# === Cleaning cihi_children_youth ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/cihi_children_youth.csv  shape=(4320, 8)
#
# === Cleaning mhacs_2022_pumf ===
#   Written: /home/codespace/NewProject/Data-Analyst-Mental-Health-Project/data/processed/02_cleaned/mhacs_2022_pumf.csv  shape=(9845, 606)
#
# ALL DATASETS CLEANED ✔
